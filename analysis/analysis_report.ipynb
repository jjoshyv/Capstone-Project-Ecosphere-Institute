# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# 🌍 Air Quality Analysis Report\n",
    "### Pipeline Summary: Trends, Forecasts & Clustering (EPA O₃)\n",
    "\n",
    "This notebook summarizes the outputs from your end-to-end ETL and analysis pipeline.\n",
    "\n",
    "#### Data Sources\n",
    "- Input file: `Cleaned_EPA_O3_Monthly.csv`\n",
    "- Feature dataset: `data_lake/feature_sets/features.parquet`\n",
    "- Trend outputs: `analysis_outputs/trends/`\n",
    "- Forecast outputs: `analysis_outputs/forecasts/`\n",
    "- Clustering outputs (if available): `analysis_outputs/clusters/`\n"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 1️⃣ Load Libraries & Data"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "import pandas as pd\n",
    "import matplotlib.pyplot as plt\n",
    "import seaborn as sns\n",
    "import json, os\n",
    "from pathlib import Path\n",
    "\n",
    "sns.set(style='whitegrid', context='talk')\n",
    "\n",
    "# Define paths\n",
    "features_path = Path('data_lake/feature_sets/features.parquet')\n",
    "trend_summary_path = Path('analysis_outputs/trends/trend_summary.csv')\n",
    "forecast_summary_path = Path('analysis_outputs/forecasts/forecast_summary.csv')\n",
    "forecast_csv = Path('analysis_outputs/forecasts/forecast_O3.csv')\n",
    "forecast_plot = Path('analysis_outputs/forecasts/forecast_O3.png')\n",
    "cluster_status_path = Path('analysis_outputs/clusters/status.json') if Path('analysis_outputs/clusters/').exists() else None\n",
    "\n",
    "# Load data safely\n",
    "df = pd.read_parquet(features_path)\n",
    "trend_summary = pd.read_csv(trend_summary_path) if trend_summary_path.exists() else None\n",
    "forecast_summary = pd.read_csv(forecast_summary_path) if forecast_summary_path.exists() else None\n",
    "forecast_df = pd.read_csv(forecast_csv, parse_dates=['date']) if forecast_csv.exists() else None\n",
    "\n",
    "print('✅ Data loaded successfully!')\n",
    "print('Feature dataset shape:', df.shape)\n",
    "print('Columns:', df.columns.tolist())\n",
    "print('Unique locations:', df['location_inferred'].unique())"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 2️⃣ Explore Time Series Trends"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Plot O3 concentration over time\n",
    "plt.figure(figsize=(12,6))\n",
    "sns.lineplot(data=df, x='date', y='O3_ug_m3', label='O₃ Concentration (µg/m³)')\n",
    "plt.title('Monthly O₃ Concentration Trend')\n",
    "plt.xlabel('Date')\n",
    "plt.ylabel('O₃ (µg/m³)')\n",
    "plt.tight_layout()\n",
    "plt.show()\n",
    "\n",
    "if trend_summary is not None:\n",
    "    display(trend_summary.head())"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 3️⃣ Forecast Visualization"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "if forecast_df is not None:\n",
    "    plt.figure(figsize=(12,6))\n",
    "    sns.lineplot(data=forecast_df, x='date', y='yhat', label='Forecast')\n",
    "    if 'yhat_lower' in forecast_df.columns and 'yhat_upper' in forecast_df.columns:\n",
    "        plt.fill_between(forecast_df['date'], forecast_df['yhat_lower'], forecast_df['yhat_upper'], alpha=0.3, label='Confidence Interval')\n",
    "    plt.title('10-Year Forecast (Prophet Model)')\n",
    "    plt.xlabel('Date')\n",
    "    plt.ylabel('Predicted O₃ (µg/m³)')\n",
    "    plt.legend()\n",
    "    plt.tight_layout()\n",
    "    plt.show()\n",
    "else:\n",
    "    print('⚠️ Forecast data not found — please run forecasting script first.')"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 4️⃣ Forecast Summary"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "if forecast_summary is not None:\n",
    "    display(forecast_summary)\n",
    "else:\n",
    "    print('⚠️ forecast_summary.csv not found.')"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 5️⃣ Clustering Summary (if available)"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "if cluster_status_path and cluster_status_path.exists():\n",
    "    with open(cluster_status_path, 'r') as f:\n",
    "        cluster_status = json.load(f)\n",
    "    print('🟡 Clustering Status:', cluster_status.get('status'))\n",
    "    print('Distinct Locations:', cluster_status.get('n_locations'))\n",
    "else:\n",
    "    print('⚠️ No clustering output found (only 1 location detected).')"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 6️⃣ Summary of Findings"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "print('📋 Summary:')\n",
    "print('- O₃ trend plotted successfully.')\n",
    "print('- Forecast generated with Prophet for 10 years.')\n",
    "print('- Clustering skipped (need ≥2 distinct locations).')\n",
    "print('- Ready to extend for multi-site datasets.')"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": "3.11"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 29
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "markdown",
#       5    "metadata": {},
#       6    "source": [
#       7     "# 🌍 Air Quality Analysis Report\n",
#       8     "### Pipeline Summary: Trends, Forecasts & Clustering (EPA O₃)\n",
#       9     "\n",
#      10     "This notebook summarizes the outputs from your end-to-end ETL and analysis pipeline.\n",
#      11     "\n",
#      12     "#### Data Sources\n",
#      13     "- Input file: `Cleaned_EPA_O3_Monthly.csv`\n",
#      14     "- Feature dataset: `data_lake/feature_sets/features.parquet`\n",
#      15     "- Trend outputs: `analysis_outputs/trends/`\n",
#      16     "- Forecast outputs: `analysis_outputs/forecasts/`\n",
#      17     "- Clustering outputs (if available): `analysis_outputs/clusters/`\n"
#      18    ]
#      19   },
#      20   {
#      21    "cell_type": "markdown",
#      22    "metadata": {},
#      23    "source": [
#      24     "## 1️⃣ Load Libraries & Data"
#      25    ]
#      26   },
#      27   {
#      28    "cell_type": "code",
# ---> 29    "execution_count": null,
#      30    "metadata": {},
#      31    "outputs": [],
#      32    "source": [
#      33     "import pandas as pd\n",
#      34     "import matplotlib.pyplot as plt\n",
#      35     "import seaborn as sns\n",
#      36     "import json, os\n",
#      37     "from pathlib import Path\n",
#      38     "\n",
#      39     "sns.set(style='whitegrid', context='talk')\n",
#      40     "\n",
#      41     "# Define paths\n",
#      42     "features_path = Path('data_lake/feature_sets/features.parquet')\n",
#      43     "trend_summary_path = Path('analysis_outputs/trends/trend_summary.csv')\n",
#      44     "forecast_summary_path = Path('analysis_outputs/forecasts/forecast_summary.csv')\n",
#      45     "forecast_csv = Path('analysis_outputs/forecasts/forecast_O3.csv')\n",
#      46     "forecast_plot = Path('analysis_outputs/forecasts/forecast_O3.png')\n",
#      47     "cluster_status_path = Path('analysis_outputs/clusters/status.json') if Path('analysis_outputs/clusters/').exists() else None\n",
#      48     "\n",
#      49     "# Load data safely\n",
#      50     "df = pd.read_parquet(features_path)\n",
#      51     "trend_summary = pd.read_csv(trend_summary_path) if trend_summary_path.exists() else None\n",
#      52     "forecast_summary = pd.read_csv(forecast_summary_path) if forecast_summary_path.exists() else None\n",
#      53     "forecast_df = pd.read_csv(forecast_csv, parse_dates=['date']) if forecast_csv.exists() else None\n",
#      54     "\n",
#      55     "print('✅ Data loaded successfully!')\n",
#      56     "print('Feature dataset shape:', df.shape)\n",
#      57     "print('Columns:', df.columns.tolist())\n",
#      58     "print('Unique locations:', df['location_inferred'].unique())"
#      59    ]
#      60   },
#      61   {
#      62    "cell_type": "markdown",
#      63    "metadata": {},
#      64    "source": [
#      65     "## 2️⃣ Explore Time Series Trends"
#      66    ]
#      67   },
#      68   {
#      69    "cell_type": "code",
#      70    "execution_count": null,
#      71    "metadata": {},
#      72    "outputs": [],
#      73    "source": [
#      74     "# Plot O3 concentration over time\n",
#      75     "plt.figure(figsize=(12,6))\n",
#      76     "sns.lineplot(data=df, x='date', y='O3_ug_m3', label='O₃ Concentration (µg/m³)')\n",
#      77     "plt.title('Monthly O₃ Concentration Trend')\n",
#      78     "plt.xlabel('Date')\n",
#      79     "plt.ylabel('O₃ (µg/m³)')\n",
#      80     "plt.tight_layout()\n",
#      81     "plt.show()\n",
#      82     "\n",
#      83     "if trend_summary is not None:\n",
#      84     "    display(trend_summary.head())"
#      85    ]
#      86   },
#      87   {
#      88    "cell_type": "markdown",
#      89    "metadata": {},
#      90    "source": [
#      91     "## 3️⃣ Forecast Visualization"
#      92    ]
#      93   },
#      94   {
#      95    "cell_type": "code",
#      96    "execution_count": null,
#      97    "metadata": {},
#      98    "outputs": [],
#      99    "source": [
#     100     "if forecast_df is not None:\n",
#     101     "    plt.figure(figsize=(12,6))\n",
#     102     "    sns.lineplot(data=forecast_df, x='date', y='yhat', label='Forecast')\n",
#     103     "    if 'yhat_lower' in forecast_df.columns and 'yhat_upper' in forecast_df.columns:\n",
#     104     "        plt.fill_between(forecast_df['date'], forecast_df['yhat_lower'], forecast_df['yhat_upper'], alpha=0.3, label='Confidence Interval')\n",
#     105     "    plt.title('10-Year Forecast (Prophet Model)')\n",
#     106     "    plt.xlabel('Date')\n",
#     107     "    plt.ylabel('Predicted O₃ (µg/m³)')\n",
#     108     "    plt.legend()\n",
#     109     "    plt.tight_layout()\n",
#     110     "    plt.show()\n",
#     111     "else:\n",
#     112     "    print('⚠️ Forecast data not found — please run forecasting script first.')"
#     113    ]
#     114   },
#     115   {
#     116    "cell_type": "markdown",
#     117    "metadata": {},
#     118    "source": [
#     119     "## 4️⃣ Forecast Summary"
#     120    ]
#     121   },
#     122   {
#     123    "cell_type": "code",
#     124    "execution_count": null,
#     125    "metadata": {},
#     126    "outputs": [],
#     127    "source": [
#     128     "if forecast_summary is not None:\n",
#     129     "    display(forecast_summary)\n",
#     130     "else:\n",
#     131     "    print('⚠️ forecast_summary.csv not found.')"
#     132    ]
#     133   },
#     134   {
#     135    "cell_type": "markdown",
#     136    "metadata": {},
#     137    "source": [
#     138     "## 5️⃣ Clustering Summary (if available)"
#     139    ]
#     140   },
#     141   {
#     142    "cell_type": "code",
#     143    "execution_count": null,
#     144    "metadata": {},
#     145    "outputs": [],
#     146    "source": [
#     147     "if cluster_status_path and cluster_status_path.exists():\n",
#     148     "    with open(cluster_status_path, 'r') as f:\n",
#     149     "        cluster_status = json.load(f)\n",
#     150     "    print('🟡 Clustering Status:', cluster_status.get('status'))\n",
#     151     "    print('Distinct Locations:', cluster_status.get('n_locations'))\n",
#     152     "else:\n",
#     153     "    print('⚠️ No clustering output found (only 1 location detected).')"
#     154    ]
#     155   },
#     156   {
#     157    "cell_type": "markdown",
#     158    "metadata": {},
#     159    "source": [
#     160     "## 6️⃣ Summary of Findings"
#     161    ]
#     162   },
#     163   {
#     164    "cell_type": "code",
#     165    "execution_count": null,
#     166    "metadata": {},
#     167    "outputs": [],
#     168    "source": [
#     169     "print('📋 Summary:')\n",
#     170     "print('- O₃ trend plotted successfully.')\n",
#     171     "print('- Forecast generated with Prophet for 10 years.')\n",
#     172     "print('- Clustering skipped (need ≥2 distinct locations).')\n",
#     173     "print('- Ready to extend for multi-site datasets.')"
#     174    ]
#     175   }
#     176  ],
#     177  "metadata": {
#     178   "kernelspec": {
#     179    "display_name": "Python 3",
#     180    "language": "python",
#     181    "name": "python3"
#     182   },
#     183   "language_info": {
#     184    "name": "python",
#     185    "version": "3.11"
#     186   }
#     187  },
#     188  "nbformat": 4,
#     189  "nbformat_minor": 5
#     190 }
#
# NameError: name 'null' is not defined
